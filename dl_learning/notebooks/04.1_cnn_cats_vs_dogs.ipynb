# %% [markdown]
# Transfer Learning (Cats vs Dogs) mini-project.

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
from tensorflow.keras.utils import get_file

# %%
base_dir = r"C:\Users\Shail\.keras\datasets\cats_and_dogs_extracted\cats_and_dogs_filtered"

train_dir = os.path.join(base_dir, "train")
validation_dir = os.path.join(base_dir, "validation")

train_cats_dir = os.path.join(train_dir, "cats")
train_dogs_dir = os.path.join(train_dir, "dogs")

val_cats_dir = os.path.join(validation_dir, "cats")
val_dogs_dir = os.path.join(validation_dir, "dogs")

print("Train cats:", len(os.listdir(train_cats_dir)))
print("Train dogs:", len(os.listdir(train_dogs_dir)))
print("Val cats:", len(os.listdir(val_cats_dir)))
print("Val dogs:", len(os.listdir(val_dogs_dir)))
# Out:
# C:\Users\Shail\.keras\datasets\cats_and_dogs_extracted

# %%
print(zip_path)
print(os.listdir(os.path.dirname(zip_path)))
# Out:
# C:\Users\Shail\.keras\datasets\cats_and_dogs_extracted
# ['cats_and_dogs.zip', 'cats_and_dogs_extracted', 'cats_and_dogs_filtered.zip', 'cats_and_dogs_filtered_extracted', 'mnist.npz']
